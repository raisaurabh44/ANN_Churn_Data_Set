# %% [markdown]
# <a href="https://colab.research.google.com/github/raisaurabh44/ANN_Churn_Data_Set/blob/main/ANN_Churn_Data_Set.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Imports

# %%
# Data input
import pandas as pd
import numpy as np

#Visualisation libraries
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# # File Handling

# %%
df=pd.read_csv("/content/sample_data/Churn.csv")

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %% [markdown]
# # EDA - Exploratory Data Analysis

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# min         0.000000       1.000000      0.00000        0.000000
# 25%         0.000000       1.000000      0.00000        0.000000
# 50%     97198.540000       1.000000      1.00000        1.000000
# 75%    127644.240000       2.000000      1.00000        1.000000
# max    250898.090000       4.000000      1.00000        1.000000
#
#        EstimatedSalary        Exited
# count     10000.000000  10000.000000
# mean     100090.239881      0.203700
# std       57510.492818      0.402769
# min          11.580000      0.000000
# 25%       51002.110000      0.000000
# 50%      100193.915000      0.000000
# 75%      149388.247500      0.000000
# max      199992.480000      1.000000

# %% [markdown]
# # Univariate Analysis - Categorical/Numerical

# %%
df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
categorical_variables=['Geography','Gender','HasCrCard','NumOfProducts','IsActiveMember','Exited','Tenure']
numerical_variables = list(set(df.columns) - set(categorical_variables))

# %%
numerical_variables.remove('RowNumber')
numerical_variables.remove('CustomerId')
numerical_variables.remove('Surname')

# %%
categorical_variables
# Out:
# ['Geography',
#  'Gender',
#  'HasCrCard',
#  'NumOfProducts',
#  'IsActiveMember',
#  'Exited',
#  'Tenure']

# %%
numerical_variables
# Out:
# ['Balance', 'EstimatedSalary', 'CreditScore', 'Age']

# %% [markdown]
# ## Categorical Variables

# %%
for feat in categorical_variables:
    print(feat)
    print()
#     print(df[feat].value_counts())
#     print("-"*50)
    print(df[feat].value_counts(normalize=True)*100)
    print("-"*50)
    print(df[feat].value_counts().plot.bar())
    plt.show()
    print("*"*50)
# Out:
# Geography
#
# Geography
# France     50.14
# Germany    25.09
# Spain      24.77
# Name: proportion, dtype: float64
# --------------------------------------------------
# Axes(0.125,0.11;0.775x0.77)
# **************************************************
# Gender
#
# Gender
# Male      54.57
# Female    45.43
# Name: proportion, dtype: float64
# --------------------------------------------------
# Axes(0.125,0.11;0.775x0.77)
# **************************************************
# HasCrCard
#
# HasCrCard
# 1    70.55
# 0    29.45
# Name: proportion, dtype: float64
# --------------------------------------------------
# Axes(0.125,0.11;0.775x0.77)
# **************************************************
# NumOfProducts
#
# NumOfProducts
# 1    50.84
# 2    45.90
# 3     2.66
# 4     0.60
# Name: proportion, dtype: float64
# --------------------------------------------------
# Axes(0.125,0.11;0.775x0.77)
# **************************************************
# IsActiveMember
#
# IsActiveMember
# 1    51.51
# 0    48.49
# Name: proportion, dtype: float64
# --------------------------------------------------
# Axes(0.125,0.11;0.775x0.77)
# **************************************************
# Exited
#
# Exited
# 0    79.63
# 1    20.37
# Name: proportion, dtype: float64
# --------------------------------------------------
# Axes(0.125,0.11;0.775x0.77)
# **************************************************
# Tenure
#
# Tenure
# 2     10.48
# 1     10.35
# 7     10.28
# 8     10.25
# 5     10.12
# 3     10.09
# 4      9.89
# 9      9.84
# 6      9.67
# 10     4.90
# 0      4.13
# Name: proportion, dtype: float64
# --------------------------------------------------
# Axes(0.125,0.11;0.775x0.77)
# **************************************************

# %% [markdown]
# ## Numerical Features

# %%
for feat in numerical_variables:
    print(feat)
    sns.boxplot(df[feat],orient='h')
    plt.show()
    print("*"*50)
# Out:
# Balance
# **************************************************
# EstimatedSalary
# **************************************************
# CreditScore
# **************************************************
# Age
# **************************************************

# %% [markdown]
# # Bivarate Analysis - two variables at a time

# %%
for feat in numerical_variables:
    print(feat)
    sns.boxplot(x='Exited',y=feat,data=df)
    plt.show()
    print("*"*50)
# Out:
# Balance
# **************************************************
# EstimatedSalary
# **************************************************
# CreditScore
# **************************************************
# Age
# **************************************************

# %% [markdown]
# # Multivariate ANalysis

# %%
smap=sns.light_palette("green")
sns.heatmap(df[numerical_variables].corr(),cmap=smap)
# Out:
# <Axes: >

# %%
variable=numerical_variables +['Exited']

# %%
sns.pairplot(df[variable],hue='Exited')

# %% [markdown]
# # Modeling

# %%
df['Geography'].unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
df['Gender']=df['Gender'].map({'Female':1, 'Male':0}).astype('int')
df['Geography']=df['Geography'].map({'France':0, 'Spain':1, 'Germany':2}).astype('int')

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore  Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619          0       1   42
# 1          2    15647311      Hill          608          1       1   41
# 2          3    15619304      Onio          502          0       1   42
# 3          4    15701354      Boni          699          0       1   39
# 4          5    15737888  Mitchell          850          1       1   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
numerical_variables+categorical_variables
# Out:
# ['Balance',
#  'EstimatedSalary',
#  'CreditScore',
#  'Age',
#  'Geography',
#  'Gender',
#  'HasCrCard',
#  'NumOfProducts',
#  'IsActiveMember',
#  'Exited',
#  'Tenure']

# %%
churn=df.loc[:,numerical_variables+categorical_variables]

# %%
churn.head()
# Out:
#      Balance  EstimatedSalary  CreditScore  Age  Geography  Gender  HasCrCard  \
# 0       0.00        101348.88          619   42          0       1          1
# 1   83807.86        112542.58          608   41          1       1          0
# 2  159660.80        113931.57          502   42          0       1          1
# 3       0.00         93826.63          699   39          0       1          0
# 4  125510.82         79084.10          850   43          1       1          1
#
#    NumOfProducts  IsActiveMember  Exited  Tenure
# 0              1               1       1       2
# 1              1               1       0       1
# 2              3               0       1       8
# 3              2               0       0       1
# 4              1               1       0       2

# %%
X=churn.drop(columns='Exited')
y=churn.loc[:,'Exited']

# %%
# Train Test
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape )
# Out:
# (6700, 10) (3300, 10) (6700,) (3300,)

# %% [markdown]
# # Model using sklearn classifier

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(random_state=0)

# %%
clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
y_pred=clf.predict(X_test)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 1])

# %%
y_test
# Out:
# 6252    0
# 4684    0
# 1731    0
# 4742    0
# 4521    0
#        ..
# 1744    0
# 9754    0
# 6094    0
# 8781    0
# 9401    1
# Name: Exited, Length: 3300, dtype: int64

# %% [markdown]
# # Model Evaluation

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.86      0.87      2657
#            1       0.45      0.50      0.48       643
#
#     accuracy                           0.79      3300
#    macro avg       0.67      0.68      0.67      3300
# weighted avg       0.79      0.79      0.79      3300

# %% [markdown]
# # Deep Learning

# %%
# !pip install pydot

# %%
# !pip install keras
# !pip install tensorflow

# %% [markdown]
# # Keras sequential API

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import plot_model
import keras
from keras import layers
from keras import ops

# %%
classfier=Sequential()
classfier.add(Dense(5,activation='relu', input_dim=10))
# classfier.add(Dense(10, activation='relu'))
# classfier.add(Dense(100, activation='relu'))
#Output
classfier.add(Dense(1, activation='sigmoid'))

classfier.summary()
classfier.compile(optimizer='SGD', loss='binary_crossentropy', metrics=['accuracy'])
classfier.fit(X_train, y_train, epochs=10, validation_data=(X_test, y_test))
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 5)              │            55 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │             6 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 61 (244.00 B)
#  Trainable params: 61 (244.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 512us/step - accuracy: 0.7795 - loss: 113203312.0000 - val_accuracy: 0.8052 - val_loss: 0.5755
# Epoch 2/10
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 291us/step - accuracy: 0.7862 - loss: 0.5719 - val_accuracy: 0.8052 - val_loss: 0.5304
# Epoch 3/10
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 285us/step - accuracy: 0.7947 - loss: 0.5333 - val_accuracy: 0.8052 - val_loss: 0.5116
# Epoch 4/10
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 283us/step - accuracy: 0.7924 - loss: 0.5216 - val_accuracy: 0.8052 - val_loss: 0.5031
# Epoch 5/10
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 294us/step - accuracy: 0.7983 - loss: 0.5094 - val_accuracy: 0.8052 - val_loss: 0.4990
# Epoch 6/10
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 287us/step - accuracy: 0.7903 - loss: 0.5158 - val_accuracy: 0.8052 - val_loss: 0.4968
# Epoch 7/10
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 281us/step - accuracy: 0.8018 - loss: 0.5006 - val_accuracy: 0.8052 - val_loss: 0.4956
# Epoch 8/10
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 289us/step - accuracy: 0.7902 - loss: 0.5142 - val_accuracy: 0.8052 - val_loss: 0.4949
# Epoch 9/10
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 295us/step - accuracy: 0.7957 - loss: 0.5068 - val_accuracy: 0.8052 - val_loss: 0.4945
# Epoch 10/10
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 285us/step - accuracy: 0.7911 - loss: 0.5126 - val_accuracy: 0.8052 - val_loss: 0.4942

# %%
keras.utils.plot_model(classfier, "my_first_model.png",show_shapes=True, show_layer_names=True)

# %% [markdown]
# https://keras.io/guides/sequential_model/
# ![image.png](attachment:67f516c6-caf7-4b5d-8876-2c002957dbec.png)

# %%
# Define Sequential model with 3 layers
model_alternate = keras.Sequential(
    [
        layers.Dense(5, activation="relu", name="layer1",input_dim=10),
        layers.Dense(1, activation="sigmoid", name="layer2")
    ]
)

model_alternate.summary()
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ layer1 (Dense)                  │ (None, 5)              │            55 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer2 (Dense)                  │ (None, 1)              │             6 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 61 (244.00 B)
#  Trainable params: 61 (244.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
keras.utils.plot_model(model_alternate, "my_first_model.png",show_shapes=True, show_layer_names=True)

# %%
model_alternate.compile(optimizer='SGD', loss='binary_crossentropy', metrics=['accuracy'])
model_alternate.fit(X_train, y_train, epochs=10, validation_data=(X_test, y_test))
# Out:
# Epoch 1/10
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 544us/step - accuracy: 0.7805 - loss: 15660603.0000 - val_accuracy: 0.8052 - val_loss: 0.5755
# Epoch 2/10
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 297us/step - accuracy: 0.7862 - loss: 0.5721 - val_accuracy: 0.8052 - val_loss: 0.5304
# Epoch 3/10
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 288us/step - accuracy: 0.7935 - loss: 0.5343 - val_accuracy: 0.8052 - val_loss: 0.5116
# Epoch 4/10
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 291us/step - accuracy: 0.7922 - loss: 0.5218 - val_accuracy: 0.8052 - val_loss: 0.5030
# Epoch 5/10
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 289us/step - accuracy: 0.7959 - loss: 0.5120 - val_accuracy: 0.8052 - val_loss: 0.4989
# Epoch 6/10
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 296us/step - accuracy: 0.7845 - loss: 0.5224 - val_accuracy: 0.8052 - val_loss: 0.4967
# Epoch 7/10
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 288us/step - accuracy: 0.7899 - loss: 0.5150 - val_accuracy: 0.8052 - val_loss: 0.4955
# Epoch 8/10
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 316us/step - accuracy: 0.7881 - loss: 0.5167 - val_accuracy: 0.8052 - val_loss: 0.4949
# Epoch 9/10
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 292us/step - accuracy: 0.7927 - loss: 0.5106 - val_accuracy: 0.8052 - val_loss: 0.4944
# Epoch 10/10
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 448us/step - accuracy: 0.7856 - loss: 0.5198 - val_accuracy: 0.8052 - val_loss: 0.4942

# %% [markdown]
# # Keras Functional API
# https://keras.io/api/models/

# %% [markdown]
# ### Using Input layer separately
# ![Screenshot 2024-07-06 at 2.27.56 PM.png](attachment:e8b251f9-759e-4865-bc7d-ec8cbf14ce87.png)

# %% [markdown]
# Purpose of the Keras Input Layer
# The primary purpose of the Input Layer in Keras is to define the input’s shape (or dimensionality). This specification is crucial because the subsequent layers in the network need to know the shape of their input tensor to correctly configure themselves. The input layer does not alter data; it simply passes it on to the next layer.

# %% [markdown]
# The Keras functional API is a way to create models that are more flexible than the keras.Sequential API. The functional API can handle models with non-linear topology, shared layers, and even multiple inputs or outputs.
#
# The main idea is that a deep learning model is usually a directed acyclic graph (DAG) of layers. So the functional API is a way to build graphs of layers.

# %% [markdown]
# ![image.png](attachment:ef6c0631-ddfb-4fda-830a-d16d5aa2cbce.png)

# %%
from keras.layers import Input

# %%
inputs=keras.Input(shape=(10,))
#Hidden
hidden=layers.Dense(5, activation="relu")(inputs)
# hidden2=layers.Dense(5, activation="relu")(hidden1)
# hidden3=layers.Dense(5, activation="relu")(hidden2)
outputs = layers.Dense(1,activation="sigmoid")(hidden)
model = keras.Model(inputs=inputs, outputs=outputs, name="churn_model")
model.summary()
# Out:
# Model: "churn_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 10)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 5)              │            55 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │             6 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 61 (244.00 B)
#  Trainable params: 61 (244.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# For reference
# classfier=Sequential()
# classfier.add(Dense(5,activation='relu', input_dim=10))
# classfier.add(Dense(1, activation='sigmoid'))
# classfier.summary()

# %%
model.compile()

# %%
model.compile(optimizer='SGD', loss='binary_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=10,  validation_data=(X_test, y_test))
# Out:
# Epoch 1/10
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 537us/step - accuracy: 0.7724 - loss: 280.0156 - val_accuracy: 0.8052 - val_loss: 0.5755
# Epoch 2/10
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 292us/step - accuracy: 0.7862 - loss: 0.5719 - val_accuracy: 0.8052 - val_loss: 0.5306
# Epoch 3/10
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 300us/step - accuracy: 0.7906 - loss: 0.5363 - val_accuracy: 0.8052 - val_loss: 0.5118
# Epoch 4/10
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 323us/step - accuracy: 0.7910 - loss: 0.5228 - val_accuracy: 0.8052 - val_loss: 0.5030
# Epoch 5/10
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 303us/step - accuracy: 0.7971 - loss: 0.5106 - val_accuracy: 0.8052 - val_loss: 0.4989
# Epoch 6/10
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 309us/step - accuracy: 0.7925 - loss: 0.5129 - val_accuracy: 0.8052 - val_loss: 0.4966
# Epoch 7/10
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 317us/step - accuracy: 0.7957 - loss: 0.5078 - val_accuracy: 0.8052 - val_loss: 0.4954
# Epoch 8/10
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 326us/step - accuracy: 0.7858 - loss: 0.5195 - val_accuracy: 0.8052 - val_loss: 0.4947
# Epoch 9/10
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 336us/step - accuracy: 0.7945 - loss: 0.5081 - val_accuracy: 0.8052 - val_loss: 0.4943
# Epoch 10/10
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 308us/step - accuracy: 0.7891 - loss: 0.5149 - val_accuracy: 0.8052 - val_loss: 0.4941

# %%
keras.utils.plot_model(model, "my_first_model.png",show_shapes=True, show_layer_names=True)

# %%
X_train
# Out:
#         Balance  EstimatedSalary  CreditScore  Age  Geography  Gender  \
# 8371  106059.40        187976.88          813   29          2       1
# 5027   73179.34         25292.53          681   37          2       0
# 9234  120688.61         24770.22          642   49          2       0
# 3944  117989.76         54129.86          612   31          0       1
# 6862       0.00          6975.02          586   33          0       0
# ...         ...              ...          ...  ...        ...     ...
# 5734   69712.74         69381.05          768   54          0       0
# 5191       0.00           706.50          682   58          0       1
# 5390       0.00         92220.12          735   38          0       1
# 860   190227.46         97508.04          667   43          0       0
# 7270  147910.30         53581.14          697   51          2       0
#
#       HasCrCard  NumOfProducts  IsActiveMember  Tenure
# 8371          0              1               0       5
# 5027          1              2               1       8
# 9234          1              1               0       4
# 3944          1              1               1       8
# 6862          1              1               0       9
# ...         ...            ...             ...     ...
# 5734          1              1               1       8
# 5191          1              1               1       1
# 5390          0              3               0       1
# 860           1              1               0       8
# 7270          1              1               1       1
#
# [6700 rows x 10 columns]

# %% [markdown]
# # How can we imporove this model

# %%
# prompt: Create a ANN network to solve this problem and achieve better accuracy than decision tree used here

# Scale the numerical features
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Build the ANN model
model = Sequential()
model.add(Dense(5, activation='relu', input_dim=10))
# model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=10,  validation_data=(X_test, y_test))

# Evaluate the model
_, accuracy = model.evaluate(X_test, y_test)
print('Accuracy: {}'.format(accuracy))
# Out:
# Epoch 1/10
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 539us/step - accuracy: 0.6542 - loss: 0.6512 - val_accuracy: 0.7709 - val_loss: 0.5160
# Epoch 2/10
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 372us/step - accuracy: 0.7805 - loss: 0.5031 - val_accuracy: 0.8009 - val_loss: 0.4539
# Epoch 3/10
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step - accuracy: 0.7925 - loss: 0.4604 - val_accuracy: 0.8061 - val_loss: 0.4356
# Epoch 4/10
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 350us/step - accuracy: 0.7953 - loss: 0.4438 - val_accuracy: 0.8085 - val_loss: 0.4285
# Epoch 5/10
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 409us/step - accuracy: 0.7956 - loss: 0.4474 - val_accuracy: 0.8082 - val_loss: 0.4247
# Epoch 6/10
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 342us/step - accuracy: 0.7972 - loss: 0.4361 - val_accuracy: 0.8106 - val_loss: 0.4215
# Epoch 7/10
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 338us/step - accuracy: 0.7955 - loss: 0.4332 - val_accuracy: 0.8127 - val_loss: 0.4189
# Epoch 8/10
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 333us/step - accuracy: 0.8024 - loss: 0.4275 - val_accuracy: 0.8121 - val_loss: 0.4161
# Epoch 9/10
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 355us/step - accuracy: 0.8027 - loss: 0.4265 - val_accuracy: 0.8127 - val_loss: 0.4139
# Epoch 10/10
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 339us/step - accuracy: 0.8044 - loss: 0.4234 - val_accuracy: 0.8139 - val_loss: 0.4114
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 177us/step - accuracy: 0.8103 - loss: 0.4206
# Accuracy: 0.8139393925666809

# %% [markdown]
# # Lets Imporve further

# %%
# Create a ANN network to solve this problem and achieve better accuracy than decision tree used here

# Scale the numerical features
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Build the ANN model
model = Sequential()
model.add(Dense(64, activation='relu', input_dim=10))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_test, y_test))

# Evaluate the model
_, accuracy = model.evaluate(X_test, y_test)
print('Accuracy: {}'.format(accuracy))
# Out:
# Epoch 1/20
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 570us/step - accuracy: 0.6848 - loss: 0.5857 - val_accuracy: 0.8264 - val_loss: 0.4017
# Epoch 2/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 359us/step - accuracy: 0.8315 - loss: 0.3941 - val_accuracy: 0.8503 - val_loss: 0.3668
# Epoch 3/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 343us/step - accuracy: 0.8422 - loss: 0.3748 - val_accuracy: 0.8591 - val_loss: 0.3560
# Epoch 4/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 349us/step - accuracy: 0.8558 - loss: 0.3546 - val_accuracy: 0.8530 - val_loss: 0.3572
# Epoch 5/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 343us/step - accuracy: 0.8555 - loss: 0.3495 - val_accuracy: 0.8627 - val_loss: 0.3444
# Epoch 6/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 342us/step - accuracy: 0.8560 - loss: 0.3493 - val_accuracy: 0.8615 - val_loss: 0.3422
# Epoch 7/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 345us/step - accuracy: 0.8508 - loss: 0.3492 - val_accuracy: 0.8652 - val_loss: 0.3401
# Epoch 8/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 358us/step - accuracy: 0.8604 - loss: 0.3311 - val_accuracy: 0.8645 - val_loss: 0.3374
# Epoch 9/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 362us/step - accuracy: 0.8605 - loss: 0.3304 - val_accuracy: 0.8655 - val_loss: 0.3380
# Epoch 10/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 361us/step - accuracy: 0.8595 - loss: 0.3309 - val_accuracy: 0.8624 - val_loss: 0.3353
# Epoch 11/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 356us/step - accuracy: 0.8612 - loss: 0.3316 - val_accuracy: 0.8645 - val_loss: 0.3343
# Epoch 12/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 350us/step - accuracy: 0.8634 - loss: 0.3266 - val_accuracy: 0.8639 - val_loss: 0.3358
# Epoch 13/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 347us/step - accuracy: 0.8638 - loss: 0.3333 - val_accuracy: 0.8648 - val_loss: 0.3361
# Epoch 14/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 343us/step - accuracy: 0.8692 - loss: 0.3132 - val_accuracy: 0.8624 - val_loss: 0.3391
# Epoch 15/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 450us/step - accuracy: 0.8686 - loss: 0.3216 - val_accuracy: 0.8606 - val_loss: 0.3403
# Epoch 16/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 362us/step - accuracy: 0.8608 - loss: 0.3196 - val_accuracy: 0.8667 - val_loss: 0.3379
# Epoch 17/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 346us/step - accuracy: 0.8687 - loss: 0.3112 - val_accuracy: 0.8588 - val_loss: 0.3374
# Epoch 18/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 347us/step - accuracy: 0.8665 - loss: 0.3196 - val_accuracy: 0.8624 - val_loss: 0.3370
# Epoch 19/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 350us/step - accuracy: 0.8632 - loss: 0.3238 - val_accuracy: 0.8648 - val_loss: 0.3332
# Epoch 20/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 347us/step - accuracy: 0.8621 - loss: 0.3169 - val_accuracy: 0.8655 - val_loss: 0.3329
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 186us/step - accuracy: 0.8620 - loss: 0.3360
# Accuracy: 0.8654545545578003

# %%
# Create a ANN network to solve this problem and achieve better accuracy than decision tree used here

# Scale the numerical features
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Build the ANN model
model = Sequential()
model.add(Dense(64, activation='relu', input_dim=10))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
history=model.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_test, y_test))

# Evaluate the model
_, accuracy = model.evaluate(X_test, y_test)
print('Accuracy: {}'.format(accuracy))
# Out:
# Epoch 1/20
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 639us/step - accuracy: 0.7167 - loss: 0.5442 - val_accuracy: 0.8297 - val_loss: 0.4089
# Epoch 2/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 368us/step - accuracy: 0.8213 - loss: 0.4156 - val_accuracy: 0.8485 - val_loss: 0.3766
# Epoch 3/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 376us/step - accuracy: 0.8453 - loss: 0.3828 - val_accuracy: 0.8545 - val_loss: 0.3539
# Epoch 4/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 491us/step - accuracy: 0.8531 - loss: 0.3597 - val_accuracy: 0.8603 - val_loss: 0.3455
# Epoch 5/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 379us/step - accuracy: 0.8573 - loss: 0.3473 - val_accuracy: 0.8603 - val_loss: 0.3404
# Epoch 6/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 402us/step - accuracy: 0.8605 - loss: 0.3363 - val_accuracy: 0.8618 - val_loss: 0.3402
# Epoch 7/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 375us/step - accuracy: 0.8645 - loss: 0.3371 - val_accuracy: 0.8639 - val_loss: 0.3402
# Epoch 8/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 367us/step - accuracy: 0.8593 - loss: 0.3393 - val_accuracy: 0.8615 - val_loss: 0.3377
# Epoch 9/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 395us/step - accuracy: 0.8611 - loss: 0.3303 - val_accuracy: 0.8652 - val_loss: 0.3352
# Epoch 10/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - accuracy: 0.8715 - loss: 0.3241 - val_accuracy: 0.8603 - val_loss: 0.3441
# Epoch 11/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step - accuracy: 0.8568 - loss: 0.3358 - val_accuracy: 0.8661 - val_loss: 0.3369
# Epoch 12/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 366us/step - accuracy: 0.8596 - loss: 0.3285 - val_accuracy: 0.8636 - val_loss: 0.3341
# Epoch 13/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step - accuracy: 0.8560 - loss: 0.3425 - val_accuracy: 0.8639 - val_loss: 0.3364
# Epoch 14/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 439us/step - accuracy: 0.8605 - loss: 0.3299 - val_accuracy: 0.8664 - val_loss: 0.3326
# Epoch 15/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 520us/step - accuracy: 0.8655 - loss: 0.3273 - val_accuracy: 0.8655 - val_loss: 0.3341
# Epoch 16/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 414us/step - accuracy: 0.8777 - loss: 0.3027 - val_accuracy: 0.8618 - val_loss: 0.3379
# Epoch 17/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 389us/step - accuracy: 0.8575 - loss: 0.3242 - val_accuracy: 0.8652 - val_loss: 0.3373
# Epoch 18/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 385us/step - accuracy: 0.8686 - loss: 0.3120 - val_accuracy: 0.8661 - val_loss: 0.3324
# Epoch 19/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 394us/step - accuracy: 0.8664 - loss: 0.3124 - val_accuracy: 0.8661 - val_loss: 0.3335
# Epoch 20/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 384us/step - accuracy: 0.8599 - loss: 0.3100 - val_accuracy: 0.8633 - val_loss: 0.3344
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 184us/step - accuracy: 0.8608 - loss: 0.3348
# Accuracy: 0.8633333444595337

# %%
# list all data in history
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# Create a ANN network to solve this problem and achieve better accuracy than decision tree used here

# Scale the numerical features
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Build the ANN model
model = Sequential()
model.add(Dense(64, activation='relu', input_dim=10))
model.add(Dense(32, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
history=model.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_test, y_test))

# Evaluate the model
_, accuracy = model.evaluate(X_test, y_test)
print('Accuracy: {}'.format(accuracy))
# Out:
# Epoch 1/20
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 643us/step - accuracy: 0.8039 - loss: 0.4908 - val_accuracy: 0.8394 - val_loss: 0.3799
# Epoch 2/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 421us/step - accuracy: 0.8363 - loss: 0.3850 - val_accuracy: 0.8482 - val_loss: 0.3629
# Epoch 3/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step - accuracy: 0.8444 - loss: 0.3615 - val_accuracy: 0.8603 - val_loss: 0.3426
# Epoch 4/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 432us/step - accuracy: 0.8563 - loss: 0.3476 - val_accuracy: 0.8618 - val_loss: 0.3463
# Epoch 5/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 434us/step - accuracy: 0.8633 - loss: 0.3294 - val_accuracy: 0.8655 - val_loss: 0.3380
# Epoch 6/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step - accuracy: 0.8632 - loss: 0.3284 - val_accuracy: 0.8606 - val_loss: 0.3469
# Epoch 7/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 449us/step - accuracy: 0.8532 - loss: 0.3400 - val_accuracy: 0.8655 - val_loss: 0.3363
# Epoch 8/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 416us/step - accuracy: 0.8628 - loss: 0.3213 - val_accuracy: 0.8618 - val_loss: 0.3373
# Epoch 9/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 415us/step - accuracy: 0.8697 - loss: 0.3185 - val_accuracy: 0.8606 - val_loss: 0.3384
# Epoch 10/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 454us/step - accuracy: 0.8648 - loss: 0.3217 - val_accuracy: 0.8645 - val_loss: 0.3434
# Epoch 11/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 410us/step - accuracy: 0.8656 - loss: 0.3113 - val_accuracy: 0.8676 - val_loss: 0.3365
# Epoch 12/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step - accuracy: 0.8776 - loss: 0.2954 - val_accuracy: 0.8630 - val_loss: 0.3421
# Epoch 13/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 392us/step - accuracy: 0.8620 - loss: 0.3107 - val_accuracy: 0.8603 - val_loss: 0.3394
# Epoch 14/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 588us/step - accuracy: 0.8711 - loss: 0.2993 - val_accuracy: 0.8630 - val_loss: 0.3471
# Epoch 15/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 406us/step - accuracy: 0.8744 - loss: 0.2991 - val_accuracy: 0.8570 - val_loss: 0.3458
# Epoch 16/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 402us/step - accuracy: 0.8768 - loss: 0.3027 - val_accuracy: 0.8615 - val_loss: 0.3402
# Epoch 17/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 430us/step - accuracy: 0.8757 - loss: 0.2972 - val_accuracy: 0.8597 - val_loss: 0.3479
# Epoch 18/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 394us/step - accuracy: 0.8681 - loss: 0.3093 - val_accuracy: 0.8603 - val_loss: 0.3545
# Epoch 19/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 421us/step - accuracy: 0.8792 - loss: 0.2859 - val_accuracy: 0.8621 - val_loss: 0.3490
# Epoch 20/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 445us/step - accuracy: 0.8781 - loss: 0.2835 - val_accuracy: 0.8533 - val_loss: 0.3529
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 213us/step - accuracy: 0.8513 - loss: 0.3542
# Accuracy: 0.8533333539962769

# %% [markdown]
# # Grid Search

# %%
# !pip install scikeras

# %%
# prompt: Can you improve this model further

# Hyperparameter Tuning using GridSearchCV
from sklearn.model_selection import GridSearchCV
from scikeras.wrappers import KerasClassifier

def create_model(optimizer='adam'):
  model = Sequential()
  model.add(Dense(64, activation='relu', input_dim=10))
  model.add(Dense(32, activation='relu'))
  model.add(Dense(1, activation='sigmoid'))
  model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
  return model

model = KerasClassifier(build_fn=create_model, verbose=0)

param_grid = {
    'batch_size': [8,16,32],
    'epochs': [10,30,50],
    'optimizer': ['adam','rmsprop','SGD']
}

grid = GridSearchCV(estimator=model, param_grid=param_grid, cv=2)
grid_result = grid.fit(X_train, y_train)

# Best parameters and accuracy
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))


# Evaluate the best model on the test set
best_model = grid_result.best_estimator_
accuracy = best_model.score(X_test, y_test)
print('Accuracy of best model: {}'.format(accuracy))
